# %%
import pandas as pd 
import requests
from bs4 import BeautifulSoup as bs

# %%
import pandas as pd 
import requests
from bs4 import BeautifulSoup as bs

# %%
url = "https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=off&as=off"
r = requests.get(url)
print(r)
soup = bs(r.content,'html5lib')
# Out:
# <Response [200]>

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# # Fetching data for One Product
# ## Fetch laptop name

# %%
product = soup.find('div',attrs={"class":"_4rR01T"})                             # >ASUS ROG Zephyrus G15 Ryzen 9 Octa Core 5900HS - (16 GB/1 TB SSD/Windows 10 Home/6 GB Graphics/NVIDIA ...</div>})
print(product.text)
# Out:
# Lenovo Ideapad Slim3 Core i3 11th Gen - (8 GB/256 GB SSD/Windows 10 Home) 14 ITL 6 Thin and Light Lapt...

# %%
product = soup.find('div',attrs={'class':'gUuXy' })
print(product.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\MONUSA~1\AppData\Local\Temp/ipykernel_2876/508366244.py in <module>
#       1 product = soup.find('div',attrs={'class':'gUuXy' })
# ----> 2 print(product.text)
#       3
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
desc = soup.find ('div',attrs={'class':"fMghEO"})
print(desc)
print('-------------')
print(desc.text)#><ul class="_1xgFaf"><li class="rgWa7D">AMD Ryzen 9 Octa Core Processor</li><li class="rgWa7D">16 GB DDR4 RAM</li><li class="rgWa7D">64 bit Windows 10 Operating System</li><li class="rgWa7D">1 TB SSD</li><li class="rgWa7D">39.62 cm (15.6 inches) Display</li><li class="rgWa7D">1 Year Onsite Warranty</li></ul></div>})
# Out:
# <div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">Intel Core i3 Processor (11th Gen)</li><li class="rgWa7D">8 GB DDR4 RAM</li><li class="rgWa7D">64 bit Windows 10 Operating System</li><li class="rgWa7D">256 GB SSD</li><li class="rgWa7D">35.56 cm (14 Inch) Display</li><li class="rgWa7D">Microsoft Office Home and Student 2019</li><li class="rgWa7D">1 Year Onsite Warranty</li></ul></div>
# -------------
# Intel Core i3 Processor (11th Gen)8 GB DDR4 RAM64 bit Windows 10 Operating System256 GB SSD35.56 cm (14 Inch) DisplayMicrosoft Office Home and Student 20191 Year Onsite Warranty

# %%
#price><span id="productRating_LSTCOMG4NWBGU4BPTP3LLHFCM_COMG4NWBGU4BPTP3_" class="_1lRcqv"><div class="_3LWZlK">4<img src="..." class="_1wB99o"></div></span><span class="_2_R_DZ"><span><span>36 Ratings&nbsp;</span><span class="_13vcmD">&amp;</span><span>&nbsp;9 Reviews</span></span></span></div><div class="_4rR01T">ASUS ROG Zephyrus G15 Ryzen 9 Octa Core 5900HS - (16 GB/1 TB SSD/Windows 10 Home/6 GB Graphics/NVIDIA ...</div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">AMD Ryzen 9 Octa Core Processor</li><li class="rgWa7D">16 GB DDR4 RAM</li><li class="rgWa7D">64 bit Windows 10 Operating System</li><li class="rgWa7D">1 TB SSD</li><li class="rgWa7D">39.62 cm (15.6 inches) Display</li><li class="rgWa7D">1 Year Onsite Warranty</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹1,45,990</div><div class="_3I9_wc _27UcVY">₹1,89,990</div><div class="_3Ay6Sb"><span>23% off</span></div></div></div><div class="_13J9qT"><img height="21" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/fa_62673a.png"></div><div class="_2ZdXDB"><div class="_3xFhiH"><div class="_2Tpdn3 _18hQoS" style="color: rgb(0, 0, 0); font-size: 14px; font-style: normal; font-weight: 400;">Upto </div><div class="_2Tpdn3 _18hQoS" style="color: rgb(0, 0, 0); font-size: 14px; font-style: normal; font-weight: 700;">₹18,100</div><div class="_2Tpdn3 _18hQoS" style="color: rgb(0, 0, 0); font-size: 14px; font-style: normal; font-weight: 400;"> Off on Exchange</div></div></div><div class="_2ZdXDB"><div class="_3xFhiH"><div class="_2Tpdn3 _18hQoS" style="color: rgb(0, 0, 0); font-size: 12px; font-style: normal; font-weight: 400;">No Cost EMI from ₹24,332/month</div></div></div></div></div>})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MONUSA~1\AppData\Local\Temp/ipykernel_10100/34087635.py in <module>
#       1 prive = soup.find('div',attrs={ 'class':"_3pLy"})
# ...

# %% [markdown]
# # Fetch Average rating (stars)
